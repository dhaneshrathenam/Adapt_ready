# %%
import pandas as pd
import numpy as np

# %%
fp = "complaints.csv"
df=pd.read_csv(fp,nrows=10000)
df
# Out:
#      Date received                                            Product  \
# 0       2024-01-23  Credit reporting or other personal consumer re...
# 1       2024-01-24  Credit reporting or other personal consumer re...
# 2       2024-01-24  Credit reporting or other personal consumer re...
# 3       2024-01-23  Credit reporting or other personal consumer re...
# 4       2024-01-23  Credit reporting or other personal consumer re...
# ...            ...                                                ...
# 9995    2024-04-10  Credit reporting or other personal consumer re...
# 9996    2024-04-10  Credit reporting or other personal consumer re...
# 9997    2024-04-13  Credit reporting or other personal consumer re...
# 9998    2024-04-15  Credit reporting or other personal consumer re...
# 9999    2024-04-15  Credit reporting or other personal consumer re...
#
#            Sub-product                                 Issue  \
# 0     Credit reporting  Incorrect information on your report
# 1     Credit reporting  Incorrect information on your report
# 2     Credit reporting           Improper use of your report
# 3     Credit reporting           Improper use of your report
# 4     Credit reporting           Improper use of your report
# ...                ...                                   ...
# 9995  Credit reporting  Incorrect information on your report
# 9996  Credit reporting  Incorrect information on your report
# 9997  Credit reporting  Incorrect information on your report
# 9998  Credit reporting  Incorrect information on your report
# 9999  Credit reporting           Improper use of your report
#
#                                               Sub-issue  \
# 0                   Information belongs to someone else
# 1                   Information belongs to someone else
# 2     Credit inquiries on your report that you don't...
# 3         Reporting company used your report improperly
# 4         Reporting company used your report improperly
# ...                                                 ...
# 9995                Information belongs to someone else
# 9996                           Account status incorrect
# 9997                Information belongs to someone else
# 9998                      Account information incorrect
# 9999  Credit inquiries on your report that you don't...
#
#                            Consumer complaint narrative  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     In accordance with the Fair Credit Reporting a...
# 4     I have observed several deviations from mandat...
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                 Company public response  \
# 0     Company has responded to the consumer and the ...
# 1     Company has responded to the consumer and the ...
# 2     Company has responded to the consumer and the ...
# 3     Company has responded to the consumer and the ...
# 4     Company has responded to the consumer and the ...
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                      Company State ZIP code           Tags  \
# 0     TRANSUNION INTERMEDIATE HOLDINGS, INC.    ME    04005            NaN
# 1     TRANSUNION INTERMEDIATE HOLDINGS, INC.    FL    33311            NaN
# 2     TRANSUNION INTERMEDIATE HOLDINGS, INC.    PA    175XX            NaN
# 3     TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    79907            NaN
# 4     TRANSUNION INTERMEDIATE HOLDINGS, INC.    NY    10075            NaN
# ...                                      ...   ...      ...            ...
# 9995     Experian Information Solutions Inc.    LA    70815            NaN
# 9996     Experian Information Solutions Inc.    TX    77043            NaN
# 9997     Experian Information Solutions Inc.    AZ    85041  Servicemember
# 9998     Experian Information Solutions Inc.    CA    91343            NaN
# 9999     Experian Information Solutions Inc.    NY    10453            NaN
#
#      Consumer consent provided? Submitted via Date sent to company  \
# 0          Consent not provided           Web           2024-01-23
# 1                         Other           Web           2024-01-24
# 2                         Other           Web           2024-01-24
# 3              Consent provided           Web           2024-01-23
# 4              Consent provided           Web           2024-01-23
# ...                         ...           ...                  ...
# 9995                        NaN           Web           2024-04-10
# 9996                        NaN           Web           2024-04-10
# 9997                        NaN           Web           2024-04-13
# 9998                        NaN           Web           2024-04-15
# 9999                        NaN           Web           2024-04-15
#
#          Company response to consumer Timely response? Consumer disputed?  \
# 0     Closed with non-monetary relief              Yes                NaN
# 1     Closed with non-monetary relief              Yes                NaN
# 2     Closed with non-monetary relief              Yes                NaN
# 3     Closed with non-monetary relief              Yes                NaN
# 4     Closed with non-monetary relief              Yes                NaN
# ...                               ...              ...                ...
# 9995                      In progress              Yes                NaN
# 9996                      In progress              Yes                NaN
# 9997                      In progress              Yes                NaN
# 9998                      In progress              Yes                NaN
# 9999                      In progress              Yes                NaN
#
#       Complaint ID
# 0          8206605
# 1          8211390
# 2          8211362
# 3          8210433
# 4          8209430
# ...            ...
# 9995       8739369
# 9996       8739356
# 9997       8763942
# 9998       8779503
# 9999       8779715
#
# [10000 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date received                 10000 non-null  object
#  1   Product                       10000 non-null  object
#  2   Sub-product                   10000 non-null  object
#  3   Issue                         10000 non-null  object
#  4   Sub-issue                     9885 non-null   object
#  5   Consumer complaint narrative  482 non-null    object
#  6   Company public response       1243 non-null   object
#  7   Company                       10000 non-null  object
#  8   State                         9984 non-null   object
#  9   ZIP code                      10000 non-null  object
#  10  Tags                          392 non-null    object
#  11  Consumer consent provided?    1731 non-null   object
#  12  Submitted via                 10000 non-null  object
#  13  Date sent to company          10000 non-null  object
#  14  Company response to consumer  10000 non-null  object
#  15  Timely response?              10000 non-null  object
#  16  Consumer disputed?            1 non-null      object
#  17  Complaint ID                  10000 non-null  int64
# dtypes: int64(1), object(17)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (10000, 18)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Nan values and shape after dealing with data in wrong format
missing_values_count = df.isnull().sum()
print(missing_values_count)
print(df.shape)
df.info()
# Out:
# Date received                      0
# Product                            0
# Sub-product                        0
# Issue                              0
# Sub-issue                        115
# Consumer complaint narrative    9518
# Company public response         8757
# Company                            0
# State                             16
# ZIP code                           0
# Tags                            9608
# Consumer consent provided?      8269
# Submitted via                      0
# Date sent to company               0
# Company response to consumer       0
# Timely response?                   0
# Consumer disputed?              9999
# Complaint ID                       0
# dtype: int64
# (10000, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date received                 10000 non-null  object
#  1   Product                       10000 non-null  object
#  2   Sub-product                   10000 non-null  object
#  3   Issue                         10000 non-null  object
#  4   Sub-issue                     9885 non-null   object
#  5   Consumer complaint narrative  482 non-null    object
#  6   Company public response       1243 non-null   object
#  7   Company                       10000 non-null  object
#  8   State                         9984 non-null   object
#  9   ZIP code                      10000 non-null  object
#  10  Tags                          392 non-null    object
#  11  Consumer consent provided?    1731 non-null   object
#  12  Submitted via                 10000 non-null  object
#  13  Date sent to company          10000 non-null  object
#  14  Company response to consumer  10000 non-null  object
#  15  Timely response?              10000 non-null  object
#  16  Consumer disputed?            1 non-null      object
#  17  Complaint ID                  10000 non-null  int64
# dtypes: int64(1), object(17)
# memory usage: 1.4+ MB
